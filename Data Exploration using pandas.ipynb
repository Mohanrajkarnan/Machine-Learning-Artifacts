# %% [markdown]
# # Day 3 started

# %%
import os # changing your working directory(Only dataset directory)
import pandas as pd
os.chdir(r'C:\Users\kishore-lpt\Downloads\datasets')
os.getcwd() #knowing your current directory
infile = pd.read_csv('mtcars.csv')

# %%
#infile.info() - gives information abt dataset
infile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# CarName    32 non-null object
# mpg        32 non-null float64
# cyl        32 non-null int64
# disp       32 non-null float64
# hp         32 non-null int64
# drat       32 non-null float64
# wt         32 non-null float64
# qsec       32 non-null float64
# vs         32 non-null int64
# am         32 non-null int64
# gear       32 non-null int64
# carb       32 non-null int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
infile.head(2)
# Out:
#          CarName   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110   3.9  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1     4
#
#    carb
# 0     4
# 1     4

# %%
infile.tail(2)
# Out:
#           CarName   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# 31     Volvo 142E  21.4    4  121.0  109  4.11  2.78  18.6   1   1     4     2

# %%
#infile['mpg'] = coloumns 
#infile['mpg'].describe()  = shows statitics value
infile['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
#mean- average
#median - Mid point
#mode - Common data (maximum no of repeated no in a column)
#25% - is called Quartile 1
#50% - is called Quartile 2
#7% - is called Quartile 3
#Q3-Q1 - is Inter quartile range(IQR)
#outliers = Unique one which is not fit to the data (ex : sedan (Shift , Bmw))
#outlier 1 = q3+(1.5*IQR)
#outlier 2 = q1-(1.5*IQR)

# %%
# %matplotlib inline
infile.boxplot('mpg')

# %%
#infile.loc[Row selection,columns selection] = get selective data
infile.loc[16:30,['CarName','mpg']]
# Out:
#               CarName   mpg
# 16  Chrysler Imperial  14.7
# 17           Fiat 128  32.4
# 18        Honda Civic  30.4
# 19     Toyota Corolla  33.9
# 20      Toyota Corona  21.5
# 21   Dodge Challenger  15.5
# 22        AMC Javelin  15.2
# 23         Camaro Z28  13.3
# 24   Pontiac Firebird  19.2
# 25          Fiat X1-9  27.3
# 26      Porsche 914-2  26.0
# 27       Lotus Europa  30.4
# 28     Ford Pantera L  15.8
# 29       Ferrari Dino  19.7
# 30      Maserati Bora  15.0

# %%
#infile.loc[Row selection,columns selection] = get selective data
infile.loc[10:12,['CarName','mpg']]
infile.loc[[0,23,30],['CarName','mpg']]
infile.loc[0:2,:]
infile.loc[: , ['CarName','mpg']]
infile.loc[infile ['mpg']>20 , :]
# Out:
#            CarName   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# ...

# %% [markdown]
# # Day 4 started

# %%
infile.loc[15:18,['CarName','am','mpg']]#select 15 to 18 sequence of rows , bring CarName , am , mpg coloumns
# Out:
#                 CarName  am   mpg
# 15  Lincoln Continental   0  10.4
# 16    Chrysler Imperial   0  14.7
# 17             Fiat 128   1  32.4
# 18          Honda Civic   1  30.4

# %%
infile.loc[[20,14],:]#select 20 and 14 rows , bring all coloumns
# Out:
#                CarName   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 20       Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 14  Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
#
#     gear  carb
# 20     3     1
# 14     3     4

# %%
infile.loc[:,['CarName']]
# Out:
#                 CarName
# 0             Mazda RX4
# 1         Mazda RX4 Wag
# 2            Datsun 710
# 3        Hornet 4 Drive
# 4     Hornet Sportabout
# 5               Valiant
# 6            Duster 360
# 7             Merc 240D
# 8              Merc 230
# 9              Merc 280
# 10            Merc 280C
# 11           Merc 450SE
# 12           Merc 450SL
# 13          Merc 450SLC
# 14   Cadillac Fleetwood
# 15  Lincoln Continental
# 16    Chrysler Imperial
# 17             Fiat 128
# 18          Honda Civic
# 19       Toyota Corolla
# 20        Toyota Corona
# 21     Dodge Challenger
# 22          AMC Javelin
# 23           Camaro Z28
# 24     Pontiac Firebird
# 25            Fiat X1-9
# 26        Porsche 914-2
# 27         Lotus Europa
# 28       Ford Pantera L
# 29         Ferrari Dino
# 30        Maserati Bora
# 31           Volvo 142E

# %%
infile.loc[infile['mpg']>28 , :] #single conditon to bring all cars which mpg greater than 28
# Out:
#            CarName   mpg  cyl  disp   hp  drat     wt   qsec  vs  am  gear  \
# 17        Fiat 128  32.4    4  78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4  75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4  71.1   65  4.22  1.835  19.90   1   1     4
# 27    Lotus Europa  30.4    4  95.1  113  3.77  1.513  16.90   1   1     5
#
#     carb
# 17     1
# 18     2
# 19     1
# 27     2

# %%
infile.loc[(infile['mpg']>28) & (infile['wt']>2) , :] #multiple conditon to bring all cars which mpg greater than 28 and weight greater than 2
# Out:
#      CarName   mpg  cyl  disp  hp  drat   wt   qsec  vs  am  gear  carb
# 17  Fiat 128  32.4    4  78.7  66  4.08  2.2  19.47   1   1     4     1

# %%
#select cars which starts from Merc
infile.loc[infile['CarName'].str.startswith('Merc')]
# Out:
#         CarName   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 7     Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4     2
# 8      Merc 230  22.8    4  140.8   95  3.92  3.15  22.9   1   0     4     2
# 9      Merc 280  19.2    6  167.6  123  3.92  3.44  18.3   1   0     4     4
# 10    Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4     4
# 11   Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4   0   0     3     3
# 12   Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6   0   0     3     3
# 13  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0   0   0     3     3

# %%
#How many automatic and manual cars are there ?
#Counts
infile['am'].value_counts()
# Out:
# 0    19
# 1    13
# Name: am, dtype: int64

# %%
#types of cylinder and counts
infile['cyl'].value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
#how many 4 cylinder and are automatic
#crosstab
#crosstab(array,array)
pd.crosstab(infile['am'],infile['cyl']) # only for catergorigal variable
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
tab1 = pd.crosstab(infile['am'],
                  infile ['cyl'])
print(tab1)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
tab1.apply(lambda v1:v1/v1.sum(),axis=0)
#axis =0, loop thru columns
# axis =1, loop thru rows
# apply will perform loop
# Out:
# cyl         4         6         8
# am
# 0    0.272727  0.571429  0.857143
# 1    0.727273  0.428571  0.142857

# %%
print(8/11)
# Out:
# 0.7272727272727273

# %%
tab1.apply(lambda v1:v1+v1.sum(),axis=1) #add
# Out:
# cyl   4   6   8
# am
# 0    22  23  31
# 1    21  16  15

# %%
print(tab1)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
#pivot table
type(infile)
# Out:
# pandas.core.frame.DataFrame

# %%
infile.pivot_table(index=['am'],
                  columns=['cyl'],
                  values='mpg',
                 aggfunc='mean')
# Out:
# cyl       4          6      8
# am
# 0    22.900  19.125000  15.05
# 1    28.075  20.566667  15.40

# %% [markdown]
# # Dataset Joinners

# %%
#append()= append values one table below 
#merge() = based on key bassed , Which is matched its get merge
#concat() = Blindly concat both fields from two file

#left  = Return all values from left
#right = Return all values from right
#outer = Return everything from left and right
#inner = It returns only matched values

eefile = pd.read_excel('File1.xlsx' , sheet_name =0)
projfile = pd.read_excel('File1.xlsx' , sheet_name =1)
mergefile = eefile.merge(projfile, left_on =['EEID'], right_on=['Employee'],how='inner')
mergefile.head()
# Out:
#    EEID  Name  Age  Project ID  Employee Project Name Location
# 0     1  Siva   44        1001         1           P1       R1
# 1     1  Siva   44        1003         1           P3       R1
# 2     2  John   37        1002         2           P2       R1
# 3     2  John   37        1004         2           P4       R2

# %%
#Saving files
mergefile.to_csv('combinedFile1.csv') # With index
mergefile.to_csv('combinedFile2.csv',index=None) # without index

# %%
#text file - fopen/read
#sql - pyodbc, pypyodbc - read from sql server
#read- json (pandas)- dictionary/nosql
#read/webscrapping - selenium / python
#api - "requests" read
#tweepy/ facebook

# %%
mergefile.sort_values(by=['Age','Project ID'],ascending=False)
# Out:
#    EEID  Name  Age  Project ID  Employee Project Name Location
# 1     1  Siva   44        1003         1           P3       R1
# 0     1  Siva   44        1001         1           P1       R1
# 3     2  John   37        1004         2           P4       R2
# 2     2  John   37        1002         2           P2       R1
